# %% [markdown]
# # Excelerate Week 1 Task

# %% [markdown]
# # Problem Statement

# %% [markdown]
# You will be analyzing data for the Marketing team. GlobalShala has been running ad campaigns on Facebook for an event called Superhero U and the Marketing team needs your help identifying at least one campaign to recommend discontinuing in order to cut costs. At the end of the week, you will select one or more ad campaigns to recommend discontinuing based on your team’s analysis.

# %%
# Import the necessary libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# loading the dataset
df = pd.read_csv('Data from marketing team - Raw Data.csv')

# %%
# to get the dataset
df
# Out:
#     Campaign ID                             Campaign Name  \
# 0    Campaign 1          SHU_6 (Educators and Principals)
# 1    Campaign 1          SHU_6 (Educators and Principals)
# 2    Campaign 1          SHU_6 (Educators and Principals)
# 3    Campaign 1          SHU_6 (Educators and Principals)
# 4    Campaign 2  SHU3_ (Students Apart from India and US)
# 5    Campaign 2  SHU3_ (Students Apart from India and US)
# 6    Campaign 2  SHU3_ (Students Apart from India and US)
# 7    Campaign 3                   SHU_Students(Australia)
# 8    Campaign 3                   SHU_Students(Australia)
# 9    Campaign 3                   SHU_Students(Australia)
# 10   Campaign 4                     SHU_Students (Canada)
# 11   Campaign 4                     SHU_Students (Canada)
# 12   Campaign 4                     SHU_Students (Canada)
# 13   Campaign 5                       SHU_Students(Ghana)
# 14   Campaign 5                       SHU_Students(Ghana)
# ...

# %%
# to get the first 5 rows
df.head()
# Out:
#   Campaign ID                             Campaign Name  \
# 0  Campaign 1          SHU_6 (Educators and Principals)
# 1  Campaign 1          SHU_6 (Educators and Principals)
# 2  Campaign 1          SHU_6 (Educators and Principals)
# 3  Campaign 1          SHU_6 (Educators and Principals)
# 4  Campaign 2  SHU3_ (Students Apart from India and US)
#
#                    Audience    Age  \
# 0  Educators and Principals  25-34
# 1  Educators and Principals  35-44
# 2  Educators and Principals  45-54
# 3  Educators and Principals  55-64
# 4                  Students  18-24
#
#                                            Geography  Reach  Impressions  \
# 0  Group 1 (Australia, Canada, United Kingdom, Gh...  11387        23283
# 1  Group 1 (Australia, Canada, United Kingdom, Gh...   8761        15683
# 2  Group 1 (Australia, Canada, United Kingdom, Gh...   2867         6283
# 3  Group 1 (Australia, Canada, United Kingdom, Gh...    889         1890
# ...

# %%
# to get the last five rows
df.tail()
# Out:
#     Campaign ID       Campaign Name  Audience    Age Geography  Reach  \
# 28  Campaign 10    SHU_Students(UK)  Students  18-24        UK    741
# 29  Campaign 10    SHU_Students(UK)  Students  25-34        UK    338
# 30  Campaign 11  SHU_Students (USA)  Students  13-17       USA   2159
# 31  Campaign 11  SHU_Students (USA)  Students  18-24       USA    305
# 32  Campaign 11  SHU_Students (USA)  Students  25-34       USA     91
#
#     Impressions  Frequency  Clicks  Unique Clicks  Unique Link Clicks (ULC)  \
# 28          785   1.059379      39             34                        20
# 29          365   1.079882      13             11                         4
# 30         2465   1.141732     126            111                        95
# 31          332   1.088525      43             37                        28
# 32          103   1.131868       9              8                         3
#
#     Click-Through Rate (CTR)  Unique Click-Through Rate (Unique CTR)  \
# ...

# %%
# to get the shape of the dataset 
df.shape
# Out:
# (33, 16)

# %% [markdown]
# It shows the dataset has 33 rows and 16 columns.

# %%
# to get the basic info of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 16 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Campaign ID                             33 non-null     object
#  1   Campaign Name                           33 non-null     object
#  2   Audience                                33 non-null     object
#  3   Age                                     33 non-null     object
#  4   Geography                               33 non-null     object
#  5   Reach                                   33 non-null     int64
#  6   Impressions                             33 non-null     int64
#  7   Frequency                               33 non-null     float64
#  8   Clicks                                  33 non-null     int64
#  9   Unique Clicks                           33 non-null     int64
# ...

# %%
# to get the statistical details of the dataset
df.describe()
# Out:
#               Reach   Impressions  Frequency       Clicks  Unique Clicks  \
# count     33.000000     33.000000  33.000000    33.000000      33.000000
# mean    5723.272727   8783.636364   1.418234   364.393939     288.000000
# std     7671.821261  11327.981290   0.471318   556.340326     432.381125
# min       91.000000    103.000000   1.042614     9.000000       8.000000
# 25%      889.000000   1874.000000   1.131868    49.000000      44.000000
# 50%     2557.000000   3146.000000   1.174759   135.000000     111.000000
# 75%     6145.000000  12372.000000   1.665733   325.000000     246.000000
# max    30110.000000  39161.000000   3.169081  2593.000000    1994.000000
#
#        Unique Link Clicks (ULC)  Click-Through Rate (CTR)  \
# count                 33.000000                 33.000000
# mean                 159.303030                  4.814551
# std                  257.960933                  2.901685
# min                    3.000000                  1.668892
# ...

# %%
# to get the column names
df.columns
# Out:
# Index(['Campaign ID', 'Campaign Name', 'Audience', 'Age', 'Geography', 'Reach',
#        'Impressions', 'Frequency', 'Clicks', 'Unique Clicks',
#        'Unique Link Clicks (ULC)', 'Click-Through Rate (CTR)',
#        'Unique Click-Through Rate (Unique CTR)', 'Amount Spent in INR',
#        'Cost Per Click (CPC)', 'Cost per Result (CPR)'],
#       dtype='object')

# %%
# to get the data types of the columns
df.dtypes
# Out:
# Campaign ID                                object
# Campaign Name                              object
# Audience                                   object
# Age                                        object
# Geography                                  object
# Reach                                       int64
# Impressions                                 int64
# Frequency                                 float64
# Clicks                                      int64
# Unique Clicks                               int64
# Unique Link Clicks (ULC)                    int64
# Click-Through Rate (CTR)                  float64
# Unique Click-Through Rate (Unique CTR)    float64
# Amount Spent in INR                       float64
# Cost Per Click (CPC)                      float64
# Cost per Result (CPR)                     float64
# dtype: object

# %%
# to get the unique values
df.nunique()
# Out:
# Campaign ID                               11
# Campaign Name                             11
# Audience                                   2
# Age                                        6
# Geography                                 11
# Reach                                     33
# Impressions                               33
# Frequency                                 33
# Clicks                                    31
# Unique Clicks                             31
# Unique Link Clicks (ULC)                  29
# Click-Through Rate (CTR)                  33
# Unique Click-Through Rate (Unique CTR)    33
# Amount Spent in INR                       33
# Cost Per Click (CPC)                      33
# Cost per Result (CPR)                     32
# dtype: int64

# %%
# to get the audience
df['Audience'].unique()
# Out:
# array(['Educators and Principals', 'Students'], dtype=object)

# %%
# to get the geography
df['Geography'].unique()
# Out:
# array(['Group 1 (Australia, Canada, United Kingdom, Ghana, Nigeria, Pakistan, United States)',
#        'Group 2 (Australia, Canada, United Kingdom, Ghana, Niger, Nigeria, Nepal, Pakistan, Thailand, Taiwan)',
#        'Australia', 'Canada', 'Ghana', 'India', 'Nepal', 'Nigeria', 'UAE',
#        'UK', 'USA'], dtype=object)

# %%
# to get the Campaign ID
df['Campaign ID'].unique()
# Out:
# array(['Campaign 1', 'Campaign 2', 'Campaign 3', 'Campaign 4',
#        'Campaign 5', 'Campaign 6', 'Campaign 7', 'Campaign 8',
#        'Campaign 9', 'Campaign 10', 'Campaign 11'], dtype=object)

# %%
# to get the Camopaign Name
df['Campaign Name'].unique()
# Out:
# array(['SHU_6 (Educators and Principals)',
#        'SHU3_ (Students Apart from India and US)',
#        'SHU_Students(Australia)', 'SHU_Students (Canada)',
#        'SHU_Students(Ghana)', 'SHU_Students (India)',
#        'SHU_Students(Nepal)', 'SHU_Students (Nigeria)',
#        'SHU_Students(UAE)', 'SHU_Students(UK)', 'SHU_Students (USA)'],
#       dtype=object)

# %%
# to get the age
df['Age'].unique()
# Out:
# array(['25-34', '35-44', '45-54', '55-64', '18-24', '13-17'], dtype=object)

# %%
# to check if the dataset has any null values(Boolean Format)
df.isnull()
# Out:
#     Campaign ID  Campaign Name  Audience    Age  Geography  Reach  \
# 0         False          False     False  False      False  False
# 1         False          False     False  False      False  False
# 2         False          False     False  False      False  False
# 3         False          False     False  False      False  False
# 4         False          False     False  False      False  False
# 5         False          False     False  False      False  False
# 6         False          False     False  False      False  False
# 7         False          False     False  False      False  False
# 8         False          False     False  False      False  False
# 9         False          False     False  False      False  False
# 10        False          False     False  False      False  False
# 11        False          False     False  False      False  False
# 12        False          False     False  False      False  False
# ...

# %%
# to check if the dataset has any null values(Numerical Format)
df.isnull().sum()
# Out:
# Campaign ID                               0
# Campaign Name                             0
# Audience                                  0
# Age                                       0
# Geography                                 0
# Reach                                     0
# Impressions                               0
# Frequency                                 0
# Clicks                                    0
# Unique Clicks                             0
# Unique Link Clicks (ULC)                  0
# Click-Through Rate (CTR)                  0
# Unique Click-Through Rate (Unique CTR)    0
# Amount Spent in INR                       0
# Cost Per Click (CPC)                      0
# Cost per Result (CPR)                     0
# dtype: int64

# %% [markdown]
# It is clear that there are no null values in the dataset. We can find this on the info function also.

# %%
# to check is the dataset has any duplicate values
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# It shows that there are no duplicate values present in the dataset.

# %%
# to get the value counts of the dataset
df.value_counts
# Out:
# <bound method DataFrame.value_counts of     Campaign ID                             Campaign Name  \
# 0    Campaign 1          SHU_6 (Educators and Principals)
# 1    Campaign 1          SHU_6 (Educators and Principals)
# 2    Campaign 1          SHU_6 (Educators and Principals)
# 3    Campaign 1          SHU_6 (Educators and Principals)
# 4    Campaign 2  SHU3_ (Students Apart from India and US)
# 5    Campaign 2  SHU3_ (Students Apart from India and US)
# 6    Campaign 2  SHU3_ (Students Apart from India and US)
# 7    Campaign 3                   SHU_Students(Australia)
# 8    Campaign 3                   SHU_Students(Australia)
# 9    Campaign 3                   SHU_Students(Australia)
# 10   Campaign 4                     SHU_Students (Canada)
# 11   Campaign 4                     SHU_Students (Canada)
# 12   Campaign 4                     SHU_Students (Canada)
# 13   Campaign 5                       SHU_Students(Ghana)
# ...

# %%
df.describe()
# Out:
#               Reach   Impressions  Frequency       Clicks  Unique Clicks  \
# count     33.000000     33.000000  33.000000    33.000000      33.000000
# mean    5723.272727   8783.636364   1.418234   364.393939     288.000000
# std     7671.821261  11327.981290   0.471318   556.340326     432.381125
# min       91.000000    103.000000   1.042614     9.000000       8.000000
# 25%      889.000000   1874.000000   1.131868    49.000000      44.000000
# 50%     2557.000000   3146.000000   1.174759   135.000000     111.000000
# 75%     6145.000000  12372.000000   1.665733   325.000000     246.000000
# max    30110.000000  39161.000000   3.169081  2593.000000    1994.000000
#
#        Unique Link Clicks (ULC)  Click-Through Rate (CTR)  \
# count                 33.000000                 33.000000
# mean                 159.303030                  4.814551
# std                  257.960933                  2.901685
# min                    3.000000                  1.668892
# ...

# %%
# to check if the dataset has any outliers we can use box plot.
# here we can only use the numerical data type columns

cols = ['Reach','Impressions', 'Frequency', 'Clicks', 'Unique Clicks',
       'Unique Link Clicks (ULC)', 'Click-Through Rate (CTR)',
       'Unique Click-Through Rate (Unique CTR)', 'Amount Spent in INR',
       'Cost Per Click (CPC)', 'Cost per Result (CPR)']
for i in cols:
    sns.boxplot(df[i], whis=1.5)
    plt.grid()
    plt.show()

# %%
# lets excecute a pairplot for the given dataset
plt.figure(figsize=(25, 15))
sns.pairplot(data=df, kind='scatter')

# %%
# lets see a distribution plot
df.hist(figsize = (15,15))
# Out:
# array([[<AxesSubplot: title={'center': 'Reach'}>,
#         <AxesSubplot: title={'center': 'Impressions'}>,
#         <AxesSubplot: title={'center': 'Frequency'}>],
#        [<AxesSubplot: title={'center': 'Clicks'}>,
#         <AxesSubplot: title={'center': 'Unique Clicks'}>,
#         <AxesSubplot: title={'center': 'Unique Link Clicks (ULC)'}>],
#        [<AxesSubplot: title={'center': 'Click-Through Rate (CTR)'}>,
#         <AxesSubplot: title={'center': 'Unique Click-Through Rate (Unique CTR)'}>,
#         <AxesSubplot: title={'center': 'Amount Spent in INR'}>],
#        [<AxesSubplot: title={'center': 'Cost Per Click (CPC)'}>,
#         <AxesSubplot: title={'center': 'Cost per Result (CPR)'}>,
#         <AxesSubplot: >]], dtype=object)

# %%
# lets visualize a heat map for the given dataset
plt.figure(figsize=(25,15))
sns.heatmap(df.corr(), annot = True)
# Out:
# <AxesSubplot: >

# %% [markdown]
# By having the heatmap, it shows some of the highest corelation between the columns. lets get the visualization of those columns.

# %%
# lets see Reach and Unique Click Links(ULC). It has corelation value of 0.94

sns.scatterplot(data=df, x='Reach', y='Unique Link Clicks (ULC)')
# Out:
# <AxesSubplot: xlabel='Reach', ylabel='Unique Link Clicks (ULC)'>

# %%
# lets see Reach and Impressions It has corelation value of 0.95

sns.scatterplot(data=df, x='Reach', y='Impressions')
# Out:
# <AxesSubplot: xlabel='Reach', ylabel='Impressions'>

# %%
# lets see Impressions and Unique Clicks. It has corelation value of 0.85

sns.scatterplot(data=df, x = 'Impressions', y = 'Unique Clicks')
# Out:
# <AxesSubplot: xlabel='Impressions', ylabel='Unique Clicks'>

# %%
# lets see Clicks and Impressions. It has corelation value of 0.83

sns.scatterplot(data=df, x = 'Clicks', y = 'Impressions')
# Out:
# <AxesSubplot: xlabel='Clicks', ylabel='Impressions'>

# %%
# Lets compare Campaign Name and Amount spent in INR
sns.barplot(data=df, x='Amount Spent in INR', y='Campaign Name')
# Out:
# <AxesSubplot: xlabel='Amount Spent in INR', ylabel='Campaign Name'>

# %% [markdown]
# From the visual it is clear that on SHU_6 (Educators and Principals) the highest amount is spent.

# %%
# Lets compare Age and Amount spent in INR
sns.barplot(data=df, x='Age', y='Amount Spent in INR')
# Out:
# <AxesSubplot: xlabel='Age', ylabel='Amount Spent in INR'>

# %% [markdown]
# Here it is clear from the visual that age category of 35-44 are more focused and highest amount spent on them.

# %%
df.columns
# Out:
# Index(['Campaign ID', 'Campaign Name', 'Audience', 'Age', 'Geography', 'Reach',
#        'Impressions', 'Frequency', 'Clicks', 'Unique Clicks',
#        'Unique Link Clicks (ULC)', 'Click-Through Rate (CTR)',
#        'Unique Click-Through Rate (Unique CTR)', 'Amount Spent in INR',
#        'Cost Per Click (CPC)', 'Cost per Result (CPR)'],
#       dtype='object')

# %%
# Lets compare Age and Reach
sns.barplot(data=df, x='Age', y='Reach')
# Out:
# <AxesSubplot: xlabel='Age', ylabel='Reach'>

# %% [markdown]
# The visual shows 18-24 years people has the more reach.

# %%
# Lets Calculate total amount spent for each campaign
total_spent = df.groupby("Campaign ID")["Amount Spent in INR"].sum()

# %%
# to get the total spent amount
total_spent
# Out:
# Campaign ID
# Campaign 1     2333.33
# Campaign 10     856.67
# Campaign 11     897.68
# Campaign 2     1579.02
# Campaign 3      850.68
# Campaign 4      923.96
# Campaign 5      837.78
# Campaign 6      955.21
# Campaign 7     1035.24
# Campaign 8      942.78
# Campaign 9      876.26
# Name: Amount Spent in INR, dtype: float64

# %%
# Lets Define performance metrics
# The following are the features which can be considered as a performance metrics and these will make an impact in the resutls
performance_metrics = ["Reach", "Impressions", "Click-Through Rate (CTR)", "Unique Click-Through Rate (Unique CTR)"]

# %%
# Lets Evaluate campaign performance based on our created performance metrics
performance_scores = df.groupby("Campaign ID")[performance_metrics].mean()

# %%
# to get the performance scores
performance_scores
# Out:
#                     Reach   Impressions  Click-Through Rate (CTR)  \
# Campaign ID
# Campaign 1    5976.000000  11784.750000                  2.730438
# Campaign 10   1212.000000   1363.666667                  3.625312
# Campaign 11    851.666667    966.666667                  8.933744
# Campaign 2   15498.000000  22437.666667                  5.929297
# Campaign 3    1062.333333   1190.666667                  4.353869
# Campaign 4    1102.333333   1422.333333                  5.513462
# Campaign 5    5008.000000   6827.666667                  3.363691
# Campaign 6   15915.500000  18623.000000                  4.303563
# Campaign 7    9889.333333  21738.333333                  2.231162
# Campaign 8    7309.666667   9658.000000                  9.852129
# Campaign 9    2444.333333   2886.666667                  2.647770
#
#              Unique Click-Through Rate (Unique CTR)
# Campaign ID
# Campaign 1                                 4.353551
# ...

# %%
# Lets Identify campaigns with high costs but relatively low performance
underperforming_campaigns = performance_scores[total_spent > 500]["Reach"].idxmin()

# %%
# For Visualization - Compare relevant columns
comparison_columns = ["Reach", "Impressions", "Clicks", "Amount Spent in INR"]
comparison_data = df.groupby("Campaign ID")[comparison_columns].sum()

# %%
# Plotting the comparison with values on top of bars
ax = comparison_data.plot(kind="bar", stacked=False, figsize=(15, 8))
plt.xlabel("Campaign ID")
plt.ylabel("Counts / Amount Spent")
plt.title("Comparison of Relevant Columns for Campaigns")
plt.show()

# %% [markdown]
# From the visual it is clear that the campaign 11 is has a poor performance with high cost.

# %%
print("Recommendation: Discontinue the following campaign due to high costs and low performance:")
print(underperforming_campaigns)
# Out:
# Recommendation: Discontinue the following campaign due to high costs and low performance:
# Campaign 11
